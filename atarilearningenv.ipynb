# %%
import os 

# %cd /kaggle/working
# !git clone https://github.com/bgaborg/atari-gym.git
# %cd /kaggle/working/atari-gym/
# !git reset --hard
# !git pull --rebase
# %ls
# %pip install uv
# !uv pip install -r pyproject.toml --system
# Out:
# /kaggle/working
# fatal: destination path 'atari-gym' already exists and is not an empty directory.
# /kaggle/working/atari-gym
# HEAD is now at 45e7ef8 add checkpoint path configuration and update related logic
# Already up to date.
# agent.py             config.json     metrics.py    pyproject.toml  wrappers.py
# checkpoints/         discord_bot.py  neural.py     README.md
# config.example.json  main.py         __pycache__/  uv.lock
# ...
# Note: you may need to restart the kernel to use updated packages.
# Using Python 3.10.12 environment at: /usr
# Resolved 50 packages in 42ms
# Audited 50 packages in 0.42ms

# %%
# %cd /kaggle/working/atari-gym
# %ls
# !cp config.example.json config.json
import json

config_file = '/kaggle/working/atari-gym/config.json'
with open(config_file, 'r') as f:
    config = json.load(f)
with open(config_file, 'w') as f:
    config["discord_webhook"] = "https://discord.com/api/webhooks/1324342638933180420/TVIGc4frTHoNM7VKJskMDUELgv_LvyRdVES6As6DX2KCP23Djjps3YC0VrOB3IS53CMX"
    config["checkpoint_path"] = "/kaggle/working/"
    config = json.dump(config, f)
# !cat /kaggle/working/atari-gym/config.json
# Out:
# /kaggle/working/atari-gym
# agent.py             config.json     metrics.py    pyproject.toml  wrappers.py
# checkpoints/         discord_bot.py  neural.py     README.md
# config.example.json  main.py         __pycache__/  uv.lock
# {"discord_webhook": "https://discord.com/api/webhooks/1324342638933180420/TVIGc4frTHoNM7VKJskMDUELgv_LvyRdVES6As6DX2KCP23Djjps3YC0VrOB3IS53CMX", "checkpoint_path": "/kaggle/working/"}

# %%
# %cd /kaggle/working/atari-gym 
# %cp -r /kaggle/working/atari-gym/checkpoints/ /kaggle/working/
# !python main.py
